# %%
#H2a1

import sys
import math 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 

y,yerr = np.loadtxt("./H2a/Mh2a1.dat", usecols=(1,2), unpack=True, comments=('#','@','&'))
f,y1,y1err = np.loadtxt("./H2a/EnoBh2a1.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
g,y2,y2err = np.loadtxt("./H2a/Eh2a1.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))


fig,ax=plt.subplots(figsize=(6.5,3.4))
plt.plot(f, y, color = 'black',label = "NCP")
plt.plot(f, y1, color = 'pink', label = "PHD + NCP")
plt.plot(f, y2, color = 'olive', label = "BPTF + NCP")

plt.fill_between(f, y-(yerr/2.2), y+(yerr/2.2),color= 'black', antialiased='True', alpha=0.3)
plt.fill_between(f, y1-(y1err/2.2), y1+(y1err/2.2),color ='pink', antialiased='True', alpha=0.3)
plt.fill_between(f, y2-(y2err/2.2), y2+(y2err/2.2),color ='olive', antialiased='True', alpha=0.3)
ax.set_ylim(0,17)
ax.set_xlim(0,129)
#plt.xticks(np.arange(45),['A1','R2','T3','K4me3','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14','A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27','S28','A29','P30','A31','T32','G33','G34','V35','K36','K37','P38','H39','R40','Y41','R42','P43', 'G44', 'T45'],rotation='vertical',fontsize=10)
ax.set_xlabel("Residue",fontsize=10)
#ax.set_yticklabels(np.arange(0,17,2), fontsize=8)
#plt.yticks(np.arange(0, 18, 2.0) )
ax.set_ylabel(r"RMSF ($\mathrm{\AA}$)",fontsize=10)
ax.legend(loc='center',labelspacing=0.1,borderpad=0.1)
plt.title("Nucleosome H2A.1 Fluctuations",fontsize=12)
plt.tight_layout()
plt.savefig('h2a1.pdf')

# %%
#H2a2

import sys
import math 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 

y,yerr = np.loadtxt("./H2a/Mh2a2.dat", usecols=(1,2), unpack=True, comments=('#','@','&'))
f,y1,y1err = np.loadtxt("./H2a/EnoBh2a2.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
g,y2,y2err = np.loadtxt("./H2a/Eh2a2.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))


fig,ax=plt.subplots(figsize=(6.5,3.4))
plt.plot(f, y, color = 'black',label = "NCP")
plt.plot(f, y1, color = 'pink', label = "PHD + NCP")
plt.plot(f, y2, color = 'olive', label = "BPTF + NCP")

plt.fill_between(f, y-(yerr/2.2), y+(yerr/2.2),color= 'black', antialiased='True', alpha=0.3)
plt.fill_between(f, y1-(y1err/2.2), y1+(y1err/2.2),color ='pink', antialiased='True', alpha=0.3)
plt.fill_between(f, y2-(y2err/2.2), y2+(y2err/2.2),color ='olive', antialiased='True', alpha=0.3)
ax.set_ylim(0,17)
ax.set_xlim(0,129)
#plt.xticks(np.arange(45),['A1','R2','T3','K4me3','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14','A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27','S28','A29','P30','A31','T32','G33','G34','V35','K36','K37','P38','H39','R40','Y41','R42','P43', 'G44', 'T45'],rotation='vertical',fontsize=10)
ax.set_xlabel("Residue",fontsize=10)
#ax.set_yticklabels(np.arange(0,17,2), fontsize=8)
#plt.yticks(np.arange(0, 18, 2.0) )
ax.set_ylabel(r"RMSF ($\mathrm{\AA}$)",fontsize=10)
ax.legend(loc='center',labelspacing=0.1,borderpad=0.1)
plt.title("Nucleosome H2A.2 Fluctuations",fontsize=12)
plt.tight_layout()
plt.savefig('h2a2.pdf')

# %%
#H2b1

import sys
import math 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 

y,yerr = np.loadtxt("./H2b/Mh2b1.dat", usecols=(1,2), unpack=True, comments=('#','@','&'))
f,y1,y1err = np.loadtxt("./H2b/EnoBh2b1.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
g,y2,y2err = np.loadtxt("./H2b/Eh2b1avg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))


fig,ax=plt.subplots(figsize=(6.5,3.4))
plt.plot(f, y, color = 'black',label = "NCP")
plt.plot(f, y1, color = 'pink', label = "PHD + NCP")
plt.plot(f, y2, color = 'olive', label = "BPTF + NCP")

plt.fill_between(f, y-(yerr/2.2), y+(yerr/2.2),color= 'black', antialiased='True', alpha=0.3)
plt.fill_between(f, y1-(y1err/2.2), y1+(y1err/2.2),color ='pink', antialiased='True', alpha=0.3)
plt.fill_between(f, y2-(y2err/2.2), y2+(y2err/2.2),color ='olive', antialiased='True', alpha=0.3)
ax.set_ylim(0,17)
ax.set_xlim(0,123)
#plt.xticks(np.arange(45),['A1','R2','T3','K4me3','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14','A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27','S28','A29','P30','A31','T32','G33','G34','V35','K36','K37','P38','H39','R40','Y41','R42','P43', 'G44', 'T45'],rotation='vertical',fontsize=10)
ax.set_xlabel("Residue",fontsize=10)
#ax.set_yticklabels(np.arange(0,17,2), fontsize=8)
#plt.yticks(np.arange(0, 18, 2.0) )
ax.set_ylabel(r"RMSF ($\mathrm{\AA}$)",fontsize=10)
ax.legend(loc='center',labelspacing=0.1,borderpad=0.1)
plt.title("Nucleosome H2B.1 Fluctuations",fontsize=12)
plt.tight_layout()
plt.savefig('h2b1.pdf')

# %%
#H2b2

import sys
import math 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 

y,yerr = np.loadtxt("./H2b/Mh2b2.dat", usecols=(1,2), unpack=True, comments=('#','@','&'))
f,y1,y1err = np.loadtxt("./H2b/EnoBh2b2.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
g,y2,y2err = np.loadtxt("./H2b/Eh2b2avg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))


fig,ax=plt.subplots(figsize=(6.5,3.4))
plt.plot(f, y, color = 'black',label = "NCP")
plt.plot(f, y1, color = 'pink', label = "PHD + NCP")
plt.plot(f, y2, color = 'olive', label = "BPTF + NCP")

plt.fill_between(f, y-(yerr/2.2), y+(yerr/2.2),color= 'black', antialiased='True', alpha=0.3)
plt.fill_between(f, y1-(y1err/2.2), y1+(y1err/2.2),color ='pink', antialiased='True', alpha=0.3)
plt.fill_between(f, y2-(y2err/2.2), y2+(y2err/2.2),color ='olive', antialiased='True', alpha=0.3)
ax.set_ylim(0,17)
ax.set_xlim(0,123)
#plt.xticks(np.arange(45),['A1','R2','T3','K4me3','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14','A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27','S28','A29','P30','A31','T32','G33','G34','V35','K36','K37','P38','H39','R40','Y41','R42','P43', 'G44', 'T45'],rotation='vertical',fontsize=10)
ax.set_xlabel("Residue",fontsize=10)
#ax.set_yticklabels(np.arange(0,17,2), fontsize=8)
#plt.yticks(np.arange(0, 18, 2.0) )
ax.set_ylabel(r"RMSF ($\mathrm{\AA}$)",fontsize=10)
ax.legend(loc='center',labelspacing=0.1,borderpad=0.1)
plt.title("Nucleosome H2B.2 Fluctuations",fontsize=12)
plt.tight_layout()
plt.savefig('h2b2.pdf')

# %%
#H2b1

import sys
import math 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 

y,yerr = np.loadtxt("./H4/Mh4.1.dat", usecols=(1,2), unpack=True, comments=('#','@','&'))
f,y1,y1err = np.loadtxt("./H4/EnoBh4.1.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
g,y2,y2err = np.loadtxt("./H4/Eh4.1avg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))


fig,ax=plt.subplots(figsize=(6.5,3.4))
plt.plot(f, y, color = 'black',label = "NCP")
plt.plot(f, y1, color = 'pink', label = "PHD + NCP")
plt.plot(f, y2, color = 'olive', label = "BPTF + NCP")

plt.fill_between(f, y-(yerr/2.2), y+(yerr/2.2),color= 'black', antialiased='True', alpha=0.3)
plt.fill_between(f, y1-(y1err/2.2), y1+(y1err/2.2),color ='pink', antialiased='True', alpha=0.3)
plt.fill_between(f, y2-(y2err/2.2), y2+(y2err/2.2),color ='olive', antialiased='True', alpha=0.3)
ax.set_ylim(0,14)
ax.set_xlim(0,103)
#plt.xticks(np.arange(45),['A1','R2','T3','K4me3','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14','A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27','S28','A29','P30','A31','T32','G33','G34','V35','K36','K37','P38','H39','R40','Y41','R42','P43', 'G44', 'T45'],rotation='vertical',fontsize=10)
ax.set_xlabel("Residue",fontsize=10)
#ax.set_yticklabels(np.arange(0,17,2), fontsize=8)
#plt.yticks(np.arange(0, 18, 2.0) )
ax.set_ylabel(r"RMSF ($\mathrm{\AA}$)",fontsize=10)
ax.legend(loc='center',labelspacing=0.1,borderpad=0.1)
plt.title("Nucleosome H4.1 Fluctuations",fontsize=12)
plt.tight_layout()
plt.savefig('h4.1.pdf')

# %%
#H2b1

import sys
import math 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 

y,yerr = np.loadtxt("./H4/Mh4.2.dat", usecols=(1,2), unpack=True, comments=('#','@','&'))
f,y1,y1err = np.loadtxt("./H4/EnoBh4.2.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
g,y2,y2err = np.loadtxt("./H4/Eh4.2avg.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))


fig,ax=plt.subplots(figsize=(6.5,3.4))
plt.plot(f, y, color = 'black',label = "NCP")
plt.plot(f, y1, color = 'pink', label = "PHD + NCP")
plt.plot(f, y2, color = 'olive', label = "BPTF + NCP")

plt.fill_between(f, y-(yerr/2.2), y+(yerr/2.2),color= 'black', antialiased='True', alpha=0.3)
plt.fill_between(f, y1-(y1err/2.2), y1+(y1err/2.2),color ='pink', antialiased='True', alpha=0.3)
plt.fill_between(f, y2-(y2err/2.2), y2+(y2err/2.2),color ='olive', antialiased='True', alpha=0.3)
ax.set_ylim(0,14)
ax.set_xlim(0,103)
#plt.xticks(np.arange(45),['A1','R2','T3','K4me3','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14','A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27','S28','A29','P30','A31','T32','G33','G34','V35','K36','K37','P38','H39','R40','Y41','R42','P43', 'G44', 'T45'],rotation='vertical',fontsize=10)
ax.set_xlabel("Residue",fontsize=10)
#ax.set_yticklabels(np.arange(0,17,2), fontsize=8)
#plt.yticks(np.arange(0, 18, 2.0) )
ax.set_ylabel(r"RMSF ($\mathrm{\AA}$)",fontsize=10)
ax.legend(loc='center',labelspacing=0.1,borderpad=0.1)
plt.title("Nucleosome H4.2 Fluctuations",fontsize=12)
plt.tight_layout()
plt.savefig('h4.2.pdf')

# %%
import statistics as stat

print('NCP H3_1-23 average is '+str(stat.mean(y[0:23]))+ ' +/- ' + str(sum(i*i for i in yerr[0:23])/2.2/23))

print('NCP+PHD H3_1-23 average is '+str(stat.mean(y1[0:23]))+ ' +/- ' + str(sum(i*i for i in y1err[0:23])/2.2/23))

print('NCP+BPTF H3_1-23 average is '+str(stat.mean(y2[0:23]))+ ' +/- ' + str(sum(i*i for i in y2err[0:23])/2.2/23))
# Out:
# NCP H3_1-23 average is 5.235252173913043 +/- 0.8693429703557313
# NCP+PHD H3_1-23 average is 5.922830434782608 +/- 1.5010410035573123
# NCP+BPTF H3_1-23 average is 6.958373913043478 +/- 1.3308566027667985

# %%
print(str(sum(i*i for i in yerr[0:2])))
print(sum(i*i for i in y2err[0:24])/2.2/23)
# Out:
# 4.70690433
# 1.3555586581027672

# %%
print('NCP H3_1-23 average is '+str(stat.mean(y[42:56]))+ ' +/- ' + str(sum(i*i for i in yerr[42:56])/28.6))

print('NCP+PHD H3_1-23 average is '+str(stat.mean(y1[42:56]))+ ' +/- ' + str(sum(i*i for i in y1err[42:56])/28.6))

print('NCP+BPTF H3_1-23 average is '+str(stat.mean(y2[42:56]))+ ' +/- ' + str(sum(i*i for i in y2err[42:56])/28.6))
# Out:
# NCP H3_1-23 average is 0.8250357142857143 +/- 0.0024997073426573425
# NCP+PHD H3_1-23 average is 1.3192 +/- 0.07341835874125872
# NCP+BPTF H3_1-23 average is 4.150157142857143 +/- 0.7628582433566433
