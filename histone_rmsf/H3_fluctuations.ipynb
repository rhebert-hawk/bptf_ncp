# %%
import sys
import math 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 

y,yerr = np.loadtxt("Nucm_h3_1.dat", usecols=(1,2), unpack=True, comments=('#','@','&'))
f,y1,y1err = np.loadtxt("EnoB_h3_1.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
g,y2,y2err = np.loadtxt("NucE_h3_1.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
x = np.array([i for i in range(0,135)])


fig,ax=plt.subplots(figsize=(7,3.4))
plt.plot(x, y, color = 'black',label = "NCP")
plt.plot(x, y1, color = 'pink', label = "PHD + NCP")
plt.plot(x, y2, color = 'olive', label = "BPTF + NCP")
#plt.plot(y2, color = 'blue', label = "H3(Tail2)")

plt.fill_between(x, y-(yerr/2.2), y+(yerr/2.2),color= 'black', antialiased='True', alpha=0.3)
plt.fill_between(x, y1-(y1err/2.2), y1+(y1err/2.2),color ='pink', antialiased='True', alpha=0.3)
plt.fill_between(x, y2-(y2err/2.2), y2+(y2err/2.2),color ='olive', antialiased='True', alpha=0.3)
ax.set_ylim(0,17)
ax.set_xlim(0,45)
plt.xticks(np.arange(45),['A1','R2','T3','K4me3','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14','A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27','S28','A29','P30','A31','T32','G33','G34','V35','K36','K37','P38','H39','R40','Y41','R42','P43', 'G44', 'T45'],rotation='vertical',fontsize=10)
#ax.set_xlabel("Residue",fontsize=10)
ax.set_yticklabels(np.arange(0,17,2), fontsize=8)
plt.yticks(np.arange(0, 18, 2.0) )
ax.set_ylabel(r"RMSF ($\mathrm{\AA}$)",fontsize=10)
plt.axvline(x=36.0, color='k', linestyle='--')
bbox_props = dict(boxstyle="larrow,pad=0.3", fc="papayawhip", ec="k", lw=2)
t = ax.text(33, 10, "Tail ", ha="center", va="center",size=12,bbox=bbox_props)
bbox_props = dict(boxstyle="rarrow,pad=0.3", fc="papayawhip", ec="k", lw=2)
t = ax.text(39.5, 10, "Core", ha="center", va="center",size=12,bbox=bbox_props)
ax.legend(loc='upper right',labelspacing=0.1,borderpad=0.1)
#plt.fill_between(x, y-error, y+error, facecolor='orange', alpha=0.3)
#plt.tight_layout()
plt.title("Nucleosome H3K4me3 1-55 Fluctuations",fontsize=12)
plt.savefig('h3k4me3_fluct.pdf')
# Out:
# /var/folders/_x/hb8mn6nd20v0bmj40xygm4n80000gn/T/ipykernel_65468/1928796863.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.arange(0,17,2), fontsize=8)

# %%
y,yerr = np.loadtxt("Nucm_h3_2.dat", usecols=(1,2), unpack=True, comments=('#','@','&'))
f,y1,y1err = np.loadtxt("EnoB_h3_2.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
g,y2,y2err = np.loadtxt("NucE_h3_2.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
x = np.array([i for i in range(0,135)])


fig,ax=plt.subplots(figsize=(7,3.4))
plt.plot(x, y, color = 'black',label = "NCP")
plt.plot(x, y1, color = 'pink', label = "PHD + NCP")
plt.plot(x, y2, color = 'olive', label = "BPTF + NCP")

plt.fill_between(x, y-(yerr/2.2), y+(yerr/2.2),color= 'black', antialiased='True', alpha=0.3)
plt.fill_between(x, y1-(y1err/2.2), y1+(y1err/2.2),color ='pink', antialiased='True', alpha=0.3)
plt.fill_between(x, y2-(y2err/2.2), y2+(y2err/2.2),color ='olive', antialiased='True', alpha=0.3)
ax.set_ylim(0,17)
ax.set_xlim(0,45)
plt.xticks(np.arange(45),['A1','R2','T3','K4','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14','A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27','S28','A29','P30','A31','T32','G33','G34','V35','K36','K37','P38','H39','R40','Y41','R42','P43', 'G44', 'T45'],rotation='vertical',fontsize=10)
#ax.set_xlabel("Residue",fontsize=10)ax.set_xlabel("Residue",fontsize=10)
ax.set_yticklabels(np.arange(0,17,2), fontsize=8)
plt.yticks(np.arange(0, 18, 2.0) )
ax.set_ylabel(r"RMSF ($\mathrm{\AA}$)",fontsize=10)
plt.axvline(x=36.0, color='k', linestyle='--')
bbox_props = dict(boxstyle="larrow,pad=0.3", fc="papayawhip", ec="k", lw=2)
t = ax.text(33, 10, "Tail ", ha="center", va="center",size=12,bbox=bbox_props)
bbox_props = dict(boxstyle="rarrow,pad=0.3", fc="papayawhip", ec="k", lw=2)
t = ax.text(39.5, 10, "Core", ha="center", va="center",size=12,bbox=bbox_props)
ax.legend(loc='upper right',labelspacing=0.1,borderpad=0.1)
#plt.tight_layout()
plt.title("Nucleosome H3 1-55 Fluctuations (No PTM)")
plt.savefig('h3_fluct.pdf')
# Out:
# /var/folders/_x/hb8mn6nd20v0bmj40xygm4n80000gn/T/ipykernel_65468/1423192875.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.arange(0,17,2), fontsize=8)

# %%
import statistics as stat

print('NCP H3_1-23 average is '+str(stat.mean(y[0:23]))+ ' +/- ' + str(sum(i*i for i in yerr[0:23])/2.2/23))

print('NCP+PHD H3_1-23 average is '+str(stat.mean(y1[0:23]))+ ' +/- ' + str(sum(i*i for i in y1err[0:23])/2.2/23))

print('NCP+BPTF H3_1-23 average is '+str(stat.mean(y2[0:23]))+ ' +/- ' + str(sum(i*i for i in y2err[0:23])/2.2/23))
# Out:
# NCP H3_1-23 average is 6.418517391304348 +/- 2.3832043513833985
# NCP+PHD H3_1-23 average is 9.42324347826087 +/- 4.918647995059289
# NCP+BPTF H3_1-23 average is 10.413552173913043 +/- 27.206858509683798

# %%
print(str(sum(i*i for i in yerr[0:2])))
print(sum(i*i for i in y2err[0:24])/2.2/23)
# Out:
# 18.39900145
# 27.822070058300397

# %%
print('NCP H3_1-23 average is '+str(stat.mean(y[42:56]))+ ' +/- ' + str(sum(i*i for i in yerr[42:56])/28.6))

print('NCP+PHD H3_1-23 average is '+str(stat.mean(y1[42:56]))+ ' +/- ' + str(sum(i*i for i in y1err[42:56])/28.6))

print('NCP+BPTF H3_1-23 average is '+str(stat.mean(y2[42:56]))+ ' +/- ' + str(sum(i*i for i in y2err[42:56])/28.6))
# Out:
# NCP H3_1-23 average is 1.0709142857142857 +/- 0.004286971328671328
# NCP+PHD H3_1-23 average is 2.0514214285714285 +/- 0.46241080104895105
# NCP+BPTF H3_1-23 average is 3.679864285714286 +/- 2.0724255

# %%
y,yerr = np.loadtxt("Nucm_h3_2.dat", usecols=(1,2), unpack=True, comments=('#','@','&'))
f,y1,y1err = np.loadtxt("EnoB_h3_2.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
g,y2,y2err = np.loadtxt("NucE_h3_2.dat", usecols=(0,1,2), unpack=True, comments=('#','@','&'))
x = np.array([i for i in range(0,135)])


fig,ax=plt.subplots(figsize=(7.6,3.4))
plt.plot(x, y, color = 'black',label = "NCP")
plt.plot(x, y1, color = 'pink', label = "PHD + NCP")
plt.plot(x, y2, color = 'olive', label = "BPTF + NCP")
#plt.plot(y2, color = 'blue', label = "H3(Tail2)")

plt.fill_between(x, y-(yerr/2.2), y+(yerr/2.2),color= 'black', antialiased='True', alpha=0.3)
plt.fill_between(x, y1-(y1err/2.2), y1+(y1err/2.2),color ='pink', antialiased='True', alpha=0.3)
plt.fill_between(x, y2-(y2err/2.2), y2+(y2err/2.2),color ='olive', antialiased='True', alpha=0.3)
ax.set_ylim(0,17)
ax.set_xlim(0,55)
plt.xticks(np.arange(55),['A1','R2','T3','K4','Q5','T6','A7','R8','K9','S10','T11','G12','G13','K14','A15','P16','R17','K18','Q19','L20','A21','T22','K23','A24','A25','R26','K27','S28','A29','P30','A31','T32','G33','G34','V35','K36','K37','P38','H39','R40','Y41','R42','P43', 'G44', 'T45', 'V46', 'A47', 'L48', 'R49', 'E50', 'I51', 'R52', 'R53', 'Y54', 'Q55' ],rotation='vertical', fontsize=10)
ax.set_xlabel("Residue",fontsize=13)
ax.set_yticklabels(np.arange(0, 18, 2), fontsize=10)
plt.yticks(np.arange(0, 18, 2.0) )
ax.set_ylabel(r"RMSF ($\mathrm{\AA}$)",fontsize=10)
plt.axvline(x=36.0, color='k', linestyle='--')
bbox_props = dict(boxstyle="larrow,pad=0.3", fc="papayawhip", ec="k", lw=2)
t = ax.text(33, 8.5, "Tail ", ha="center", va="center",size=14,bbox=bbox_props)
bbox_props = dict(boxstyle="rarrow,pad=0.3", fc="papayawhip", ec="k", lw=2)
t = ax.text(39, 8.5, "Core", ha="center", va="center",size=14,bbox=bbox_props)
ax.legend(loc='upper right',labelspacing=0.1,borderpad=0.1)
#plt.fill_between(x, y-error, y+error, facecolor='orange', alpha=0.3)
plt.tight_layout()
plt.title("Nucleosome H3 1-55 Fluctuations (No PTM)")
plt.savefig('h3_fluct.pdf')
# Out:
# /var/folders/_x/hb8mn6nd20v0bmj40xygm4n80000gn/T/ipykernel_65468/4060727908.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(np.arange(0, 18, 2), fontsize=10)

# %%
import statistics as stat

print('NCP H3_1-23 average is '+str(stat.mean(y[0:23]))+ ' +/- ' + str(sum(i*i for i in yerr[0:23])/2.2/23))

print('NCP+PHD H3_1-23 average is '+str(stat.mean(y1[0:23]))+ ' +/- ' + str(sum(i*i for i in y1err[0:23])/2.2/23))

print('NCP+BPTF H3_1-23 average is '+str(stat.mean(y2[0:23]))+ ' +/- ' + str(sum(i*i for i in y2err[0:23])/2.2/23))
# Out:
# NCP H3_1-23 average is 6.1809391304347825 +/- 2.5604087553359682
# NCP+PHD H3_1-23 average is 6.517391304347826 +/- 5.719164664822134
# NCP+BPTF H3_1-23 average is 6.710860869565217 +/- 11.147090528853754

# %%
print('NCP H3_1-23 average is '+str(stat.mean(y[42:56]))+ ' +/- ' + str(sum(i*i for i in yerr[42:56])/28.6))

print('NCP+PHD H3_1-23 average is '+str(stat.mean(y1[42:56]))+ ' +/- ' + str(sum(i*i for i in y1err[42:56])/28.6))

print('NCP+BPTF H3_1-23 average is '+str(stat.mean(y2[42:56]))+ ' +/- ' + str(sum(i*i for i in y2err[42:56])/28.6))
# Out:
# NCP H3_1-23 average is 0.9871928571428572 +/- 0.006406816433566433
# NCP+PHD H3_1-23 average is 1.332507142857143 +/- 0.07077140454545454
# NCP+BPTF H3_1-23 average is 2.7328785714285715 +/- 1.2285013583916085
