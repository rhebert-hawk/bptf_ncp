# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
font = {'family': 'sans-serif',
        'color':  'black',
        'weight': 'bold',
        'size': 10,
        }

#x,y = np.loadtxt("NTeqrg.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))

#c,d = np.loadtxt("Ebptfeqrg.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))

#e,f = np.loadtxt("2f6jeqrg.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))

x,y1 = np.loadtxt("Notail1_bptfradgyr.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))
y2 = np.loadtxt("Notail2_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y3 = np.loadtxt("Notail3_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y4 = np.loadtxt("Notail4_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y5 = np.loadtxt("Notail5_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y0 = np.concatenate((y1[-70000:],y2[-70000:],y3[-70000:],y4[-70000:],y5[-70000:]))

c,d1 = np.loadtxt("2f6jex1_bptfradgyr.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))
d2 = np.loadtxt("2f6jex2_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d3 = np.loadtxt("2f6jex3_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d4 = np.loadtxt("2f6jex4_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d5 = np.loadtxt("2f6jex5_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d0 = np.concatenate((d1[-70000:],d2[-70000:],d3[-70000:],d4[-70000:],d5[-70000:]))

e,f1 = np.loadtxt("E1_bptfradgyr.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))
f2 = np.loadtxt("E2_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f3 = np.loadtxt("E3_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f4 = np.loadtxt("E4_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f5 = np.loadtxt("E5_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f0 = np.concatenate((f1[-70000:],f2[-70000:],f3[-70000:],f4[-70000:],f5[-70000:]))

plt.figure(figsize=(3.25,3.25))

plt.hist(y0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='purple', label='Free')

plt.hist(d0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='orange', label='+Peptide')

plt.hist(f0, alpha=0.5, bins=300, linewidth=2, density=True, histtype='step', color='olive', label='+NCP')

plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.xlabel('RoG ($\AA$)', fontdict=font)
plt.ylabel('Normalized Frequency', fontdict=font)

plt.title('BPTF Radius of Gyration (RoG)', fontdict=font)
plt.legend(loc='upper left', fontsize=8)

plt.tight_layout()
#plt.margins(x=0)

#plt.savefig('histrg.pdf')
#plt.savefig('histrg.png')
#plt.savefig('histrg.svg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec

x,y1 = np.loadtxt("Notail1_bptfradgyr.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))
y2 = np.loadtxt("Notail2_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y3 = np.loadtxt("Notail3_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y4 = np.loadtxt("Notail4_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y5 = np.loadtxt("Notail5_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y0 = np.concatenate((y1[-70000:],y2[-70000:],y3[-70000:],y4[-70000:],y5[-70000:]))

yy1 = np.loadtxt("../Bromo-linker_angle/Notailangle1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy2 = np.loadtxt("../Bromo-linker_angle/Notailangle2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy3 = np.loadtxt("../Bromo-linker_angle/Notailangle3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy4 = np.loadtxt("../Bromo-linker_angle/Notailangle4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy5 = np.loadtxt("../Bromo-linker_angle/Notailangle5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy0 = np.concatenate((yy1[-70000:],yy2[-70000:],yy3[-70000:],yy4[-70000:],yy5[-70000:]))


c,d1 = np.loadtxt("2f6jex1_bptfradgyr.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))
d2 = np.loadtxt("2f6jex2_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d3 = np.loadtxt("2f6jex3_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d4 = np.loadtxt("2f6jex4_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d5 = np.loadtxt("2f6jex5_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d0 = np.concatenate((d1[-70000:],d2[-70000:],d3[-70000:],d4[-70000:],d5[-70000:]))

dd1 = np.loadtxt("../Bromo-linker_angle/2f6jexangle1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd2 = np.loadtxt("../Bromo-linker_angle/2f6jexangle2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd3 = np.loadtxt("../Bromo-linker_angle/2f6jexangle3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd4 = np.loadtxt("../Bromo-linker_angle/2f6jexangle4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd5 = np.loadtxt("../Bromo-linker_angle/2f6jexangle5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd0 = np.concatenate((dd1[-70000:],dd2[-70000:],dd3[-70000:],dd4[-70000:],dd5[-70000:]))

e,f1 = np.loadtxt("E1_bptfradgyr.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))
f2 = np.loadtxt("E2_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f3 = np.loadtxt("E3_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f4 = np.loadtxt("E4_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f5 = np.loadtxt("E5_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f0 = np.concatenate((f1[-70000:],f2[-70000:],f3[-70000:],f4[-70000:],f5[-70000:]))

ff1 = np.loadtxt("../Bromo-linker_angle/Eangle1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff2 = np.loadtxt("../Bromo-linker_angle/Eangle2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff3 = np.loadtxt("../Bromo-linker_angle/Eangle3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff4 = np.loadtxt("../Bromo-linker_angle/Eangle4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff5 = np.loadtxt("../Bromo-linker_angle/Eangle5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff0 = np.concatenate((ff1[-70000:],ff2[-70000:],ff3[-70000:],ff4[-70000:],ff5[-70000:]))

font = {'family': 'sans-serif',
        'color':  'black',
        'weight': 'bold',
        'size': 8,
        }
# Paths to your images
image_paths = ['rg17.5.png', 'rg23.6.png', 'rg29.1.png']

# Create a figure
fig = plt.figure(figsize=(6,6), dpi=300)
#fig = plt.figure()
# Create a GridSpec with 4 rows and 2 columns
gs = GridSpec(2, 4, height_ratios=[1,2])

# Add the graph subplot spanning the first column
ax_graph = fig.add_subplot(gs[0, 0:2])
ax_graph.hist(y0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='purple', label='Free')

ax_graph.hist(d0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='orange', label='+Peptide')

ax_graph.hist(f0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='olive', label='+NCP')
ax_graph.set_title('BPTF Radius of Gyration', fontdict=font)
ax_graph.set_xlabel('Radius of Gyration ($\AA$)', fontdict=font)
ax_graph.set_ylabel('Normalized Frequency', fontdict=font)
ax_graph.legend(loc='upper left', fontsize=8)

# Add image subplots in the second column
ax_image1 = fig.add_subplot(gs[1, 0])
ax_image2 = fig.add_subplot(gs[1, 1])
ax_image3 = fig.add_subplot(gs[1, 2])

# Remove axis from the image subplots
for ax in [ax_image1, ax_image2, ax_image3]:
    ax.axis('off')

# Display images
ax_image1.imshow(plt.imread(image_paths[0]))
ax_image1.set_title('17.5 $\AA$, 37.3$^\circ$', fontsize=8)

ax_image2.imshow(plt.imread(image_paths[1]))
ax_image2.set_title('23.6 $\AA$, 122.5$^\circ$', fontsize=8)

ax_image3.imshow(plt.imread(image_paths[2]))
ax_image3.set_title('29.1 $\AA$, 133.7$^\circ$', fontsize=8)


ax_graph2 = fig.add_subplot(gs[0, 2:4])

ax_graph2.hist(yy0, density=True, alpha=0.5, linewidth=2, histtype='step', bins=300, color='purple')
ax_graph2.hist(dd0, density=True, alpha=0.5, linewidth=2, histtype='step', bins=300, color='orange')
ax_graph2.hist(ff0, density=True, alpha=0.5, linewidth=2, histtype='step', bins=300, color='olive')

ax_graph2.set_xlabel('Angle (degrees)', fontdict=font)
#ax_graph2.set_ylabel('Normalized Frequency')
ax_graph2.set_title('BPTF Angle Between Domains', fontdict=font)
#plt.legend(loc='upper left')

plt.subplots_adjust(wspace=0.05)
# Adjust layout to prevent overlap
plt.tight_layout()


# Show the plot with images
#plt.savefig('histrg.pdf',bbox_inches='tight')
#plt.savefig('histrg.png',bbox_inches='tight')
#plt.savefig('histrg.svg',bbox_inches='tight')
#plt.show()

# %%
min(f0)
# Out:
# 17.5288

# %%
data_all = np.concatenate((y0,d0,f0))
counts1, bin_edges1 = np.histogram(y0, bins=300)
counts2, bin_edges2 = np.histogram(d0, bins=300)
counts3, bin_edges3 = np.histogram(f0, bins=300)
countsall, bin_edgesall = np.histogram(data_all, bins=300)

max_count_index1 = np.argmax(counts1)
mode_value1 = (bin_edges1[max_count_index1] + bin_edges1[max_count_index1 + 1]) / 2

max_count_index2 = np.argmax(counts2)
mode_value2 = (bin_edges2[max_count_index2] + bin_edges2[max_count_index2 + 1]) / 2

max_count_index3 = np.argmax(counts3)
mode_value3 = (bin_edges3[max_count_index3] + bin_edges3[max_count_index3 + 1]) / 2

max_count_indexall = np.argmax(countsall)
mode_valueall = (bin_edgesall[max_count_indexall] + bin_edgesall[max_count_indexall + 1]) / 2

print('The mode for solution BPTF is '+str(mode_value1)+' Angstroms. \n The mode for peptide+BPTF is '+str(mode_value2)+' Angstroms. \n The mode for NCP+BPTF is '+str(mode_value3)+' Angstroms. \n The overall combined mode is '+str(mode_valueall)+' Angstroms.')
# Out:
# The mode for solution BPTF is 25.025700999999998 Angstroms.
#  The mode for peptide+BPTF is 23.795981833333332 Angstroms.
#  The mode for NCP+BPTF is 21.904258 Angstroms.
#  The overall combined mode is 24.9336975 Angstroms.

# %%
import statistics as stat
print(stat.median(f0), stat.median(d0), stat.median(y0))
# Out:
# 22.0664 23.5502 22.965

# %%
np.where((d0 == stat.median(d0)))
# Out:
# (array([ 23750, 145930, 226277, 235782, 241706, 270386, 270518]),)

# %%
90806 - 70000 + 30000
# Out:
# 50806

# %%
yy0.min()
# Out:
# 43.7725

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec

# Paths to your images
image_paths = ['rg17.5.png', 'rg23.6.png', 'rg29.1.png']

# Create a figure
fig = plt.figure(figsize=(8, 6), dpi=300)

# Create a GridSpec with 2 rows and 3 columns
gs = GridSpec(2, 3)

# Add the first graph subplot (top-left) and set it as the reference for shared axes
ax_graph1 = fig.add_subplot(gs[0, 0])
ax_graph1.hist2d(y0, yy0, linewidth=2, density=True, bins=300, cmap='Greys')
ax_graph1.set_title('Free BPTF', fontdict={'size': 10})


ax_graph1.set_ylim(0,180)
ax_graph1.set_xlim(17,30)
ax_graph1.set_xticks(np.arange(17,31,4))
ax_graph1.set_yticks(np.arange(0,181,30))
ax_graph1.set_ylabel('Angle (degrees)', fontdict={'size': 8})

# Add the second and third graph subplots with shared x and y axes
ax_graph2 = fig.add_subplot(gs[0, 1])
ax_graph2.hist2d(d0, dd0, density=True, bins=300, cmap='Greys')
ax_graph2.set_title('BPTF + Peptide', fontdict={'size': 10})
ax_graph2.set_xlabel('Radius of Gyration ($\AA$)', fontdict={'size': 8})
ax_graph2.set_ylim(0,180)
ax_graph2.set_xlim(17,30)
ax_graph2.set_xticks(np.arange(17,31,4))
ax_graph2.set_yticks(np.arange(0,181,30), '')

ax_graph3 = fig.add_subplot(gs[0, 2])
ax_graph3.hist2d(f0, ff0, density=True, bins=300, cmap='Greys')
ax_graph3.set_title('BPTF + NCP', fontdict={'size': 10})
ax_graph3.set_ylim(0,180)
ax_graph3.set_xlim(17,30)
ax_graph3.set_xticks(np.arange(17,31,4))
ax_graph3.set_yticks(np.arange(0,181,30), '')

# Add the image subplots in the second row
ax_image1 = fig.add_subplot(gs[1, 0])
ax_image2 = fig.add_subplot(gs[1, 1])
ax_image3 = fig.add_subplot(gs[1, 2])

# Display images without axes
for ax, img_path, title in zip([ax_image1, ax_image2, ax_image3], image_paths, ['17.5 $\AA$, 37.3$^\circ$', '23.6 $\AA$, 122.5$^\circ$', '29.1 $\AA$, 133.7$^\circ$']):
    ax.imshow(plt.imread(img_path))
    ax.axis('off')
    ax.set_title(title, fontsize=8, y=-0.2)

# Adjust layout
#plt.tight_layout()
fig.subplots_adjust(wspace=0.3)

# Save and show the figure
#plt.savefig('histrg_fixed.pdf', bbox_inches='tight')
#plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec
from PIL import Image

# Paths to your images
image_paths = ['rg17.5.png', 'rg29.1.png']  # Removed the image for 23.6 angstroms

# Create a figure
fig = plt.figure(figsize=(6, 4.5), dpi=300)

# Create a GridSpec with 2 rows and 2 columns
gs = GridSpec(2, 2, height_ratios=[1.5,1])

# Add the first graph subplot (top-left)
ax_graph1 = fig.add_subplot(gs[0, 0])
ax_graph1.hist(y0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='purple', label='Free')
ax_graph1.hist(d0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='orange', label='+Peptide')
ax_graph1.hist(f0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='olive', label='+NCP')
ax_graph1.set_title('BPTF Radius of Gyration', fontdict={'size': 10})
ax_graph1.set_xlabel('Radius of Gyration ($\AA$)', fontdict={'size': 8})
ax_graph1.set_ylabel('Normalized Frequency', fontdict={'size': 8})


# Add the second graph subplot (top-right)
ax_graph2 = fig.add_subplot(gs[0, 1])
ax_graph2.hist(yy0, density=True, alpha=0.5, linewidth=2, histtype='step', bins=300, color='purple', label='Free')
ax_graph2.hist(dd0, density=True, alpha=0.5, linewidth=2, histtype='step', bins=300, color='orange', label='+Peptide')
ax_graph2.hist(ff0, density=True, alpha=0.5, linewidth=2, histtype='step', bins=300, color='olive', label='+NCP')
ax_graph2.set_title('BPTF Angle Between Domains', fontdict={'size': 10})
ax_graph2.set_xlabel('Angle (degrees)', fontdict={'size': 8})
ax_graph2.legend(loc='upper left', fontsize=8)

# Add the image subplot in the bottom-left
ax_image1 = fig.add_subplot(gs[1, 0])
ax_image1.imshow(plt.imread(image_paths[0]))
ax_image1.axis('off')
ax_image1.set_title('17.5 $\AA$, 37.3$^\circ$', fontsize=8, y=-0.2)

# Add the second image subplot in the bottom-right
ax_image2 = fig.add_subplot(gs[1, 1])
ax_image2.imshow(plt.imread(image_paths[1]))
ax_image2.axis('off')
ax_image2.set_title('29.1 $\AA$, 133.7$^\circ$', fontsize=8, y=-0.2)

# Adjust layout to prevent overlap
plt.tight_layout()

# Save and show the figure
plt.savefig('histrg_2x2_layout.pdf', bbox_inches='tight')
#plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec
from PIL import Image

yy1 = np.loadtxt("../Bromo-linker_angle/Notailangle1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy2 = np.loadtxt("../Bromo-linker_angle/Notailangle2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy3 = np.loadtxt("../Bromo-linker_angle/Notailangle3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy4 = np.loadtxt("../Bromo-linker_angle/Notailangle4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy5 = np.loadtxt("../Bromo-linker_angle/Notailangle5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
yy0 = np.concatenate((yy1[-70000:],yy2[-70000:],yy3[-70000:],yy4[-70000:],yy5[-70000:]))

dd1 = np.loadtxt("../Bromo-linker_angle/2f6jexangle1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd2 = np.loadtxt("../Bromo-linker_angle/2f6jexangle2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd3 = np.loadtxt("../Bromo-linker_angle/2f6jexangle3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd4 = np.loadtxt("../Bromo-linker_angle/2f6jexangle4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd5 = np.loadtxt("../Bromo-linker_angle/2f6jexangle5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
dd0 = np.concatenate((dd1[-70000:],dd2[-70000:],dd3[-70000:],dd4[-70000:],dd5[-70000:]))

ff1 = np.loadtxt("../Bromo-linker_angle/Eangle1.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff2 = np.loadtxt("../Bromo-linker_angle/Eangle2.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff3 = np.loadtxt("../Bromo-linker_angle/Eangle3.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff4 = np.loadtxt("../Bromo-linker_angle/Eangle4.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff5 = np.loadtxt("../Bromo-linker_angle/Eangle5.dat", usecols=(1), unpack=True, comments=('#','@','&'))
ff0 = np.concatenate((ff1[-70000:],ff2[-70000:],ff3[-70000:],ff4[-70000:],ff5[-70000:]))

im1 = Image.open('rg17.5.png')
im2 = Image.open('rg29.1.png')
fig = plt.figure(figsize=(5, 3), dpi=300)
gs = GridSpec(2,3)

ax1 = fig.add_subplot(gs[:,:2])

ax1.hist(yy0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='purple', label='Free')
ax1.hist(dd0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='orange', label='+Peptide')
ax1.hist(ff0, alpha=0.5, bins=300, linewidth=2, density=True, histtype='step', color='olive', label='+NCP')
ax1.set_title("BPTF Finger-linker-bromodomain Angle")
ax1.set_xlabel("Angle (degrees)")
ax1.set_ylabel("Probability Density")
ax1.legend(loc='upper left', fontsize=8)
ax2 = fig.add_subplot(gs[0,2])
ax2.imshow(im1)
ax2.axis('off')  # clear axes from graphic
ax2.set_title('37.3$^\circ$', fontsize=8, y=-0.2)

ax4 = fig.add_subplot(gs[1,2])
ax4.imshow(im2)
ax4.axis('off')  # clear axes from graphic
ax4.set_title('133.7$^\circ$', fontsize=8, y=-0.2)
plt.tight_layout()
plt.savefig("Angles.pdf")

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.gridspec import GridSpec
from PIL import Image

x,y1 = np.loadtxt("Notail1_bptfradgyr.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))
y2 = np.loadtxt("Notail2_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y3 = np.loadtxt("Notail3_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y4 = np.loadtxt("Notail4_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y5 = np.loadtxt("Notail5_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
y0 = np.concatenate((y1[-70000:],y2[-70000:],y3[-70000:],y4[-70000:],y5[-70000:]))

c,d1 = np.loadtxt("2f6jex1_bptfradgyr.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))
d2 = np.loadtxt("2f6jex2_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d3 = np.loadtxt("2f6jex3_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d4 = np.loadtxt("2f6jex4_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d5 = np.loadtxt("2f6jex5_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
d0 = np.concatenate((d1[-70000:],d2[-70000:],d3[-70000:],d4[-70000:],d5[-70000:]))

e,f1 = np.loadtxt("E1_bptfradgyr.dat", usecols=(0,1), unpack=True, comments=('#','@','&'))
f2 = np.loadtxt("E2_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f3 = np.loadtxt("E3_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f4 = np.loadtxt("E4_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f5 = np.loadtxt("E5_bptfradgyr.dat", usecols=(1), unpack=True, comments=('#','@','&'))
f0 = np.concatenate((f1[-70000:],f2[-70000:],f3[-70000:],f4[-70000:],f5[-70000:]))

im1 = Image.open('rg17.5.png')
im2 = Image.open('rg29.1.png')
fig = plt.figure(figsize=(5, 3), dpi=300)
gs = GridSpec(2,3)

ax1 = fig.add_subplot(gs[:,:2])

ax1.hist(y0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='purple', label='Free')
ax1.hist(d0, alpha=0.5, linewidth=2, density=True, bins=300, histtype='step', color='orange', label='+Peptide')
ax1.hist(f0, alpha=0.5, bins=300, linewidth=2, density=True, histtype='step', color='olive', label='+NCP')
ax1.set_title("BPTF Radius of Gyration")
ax1.set_xlabel("Radius of Gyration ($\AA$)")
ax1.set_ylabel("Probabiliy Density")
ax1.legend(loc='upper left', fontsize=7.5)

ax2 = fig.add_subplot(gs[0,2])
ax2.imshow(im1)
ax2.axis('off')  # clear axes from graphic
ax2.set_title('RoG = 17.5 $\AA$', fontsize=8, y=-0.2)

ax4 = fig.add_subplot(gs[1,2])
ax4.imshow(im2)
ax4.axis('off')  # clear axes from graphic
ax4.set_title('RoG = 29.1 $\AA$', fontsize=8, y=-0.2)
plt.tight_layout()
plt.savefig("histrg.pdf")
