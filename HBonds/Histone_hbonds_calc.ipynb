# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics as stat

# %%
# NucE

x, yh3dna1 = np.loadtxt('./current_data/Ednah3bond1series.dat', usecols = (0,1), unpack = True, comments=('#'))
ydna1 = np.loadtxt('./current_data/Ednaseries1.dat', usecols = (1), unpack = True, comments=('#'))
y1h3 = np.loadtxt('./current_data/Eh3bond1series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna2 = np.loadtxt('./current_data/Ednah3bond2series.dat', usecols = (1), unpack = True, comments=('#'))
ydna2 = np.loadtxt('./current_data/Ednaseries2.dat', usecols = (1), unpack = True, comments=('#'))
y2h3 = np.loadtxt('./current_data/Eh3bond2series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna3 = np.loadtxt('./current_data/Ednah3bond3series.dat', usecols = (1), unpack = True, comments=('#'))
ydna3 = np.loadtxt('./current_data/Ednaseries3.dat', usecols = (1), unpack = True, comments=('#'))
y3h3 = np.loadtxt('./current_data/Eh3bond3series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna4 = np.loadtxt('./current_data/Ednah3bond4series.dat', usecols = (1), unpack = True, comments=('#'))
ydna4 = np.loadtxt('./current_data/Ednaseries4.dat', usecols = (1), unpack = True, comments=('#'))
y4h3 = np.loadtxt('./current_data/Eh3bond4series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna5 = np.loadtxt('./current_data/Ednah3bond5series.dat', usecols = (1), unpack = True, comments=('#'))
ydna5 = np.loadtxt('./current_data/Ednaseries5.dat', usecols = (1), unpack = True, comments=('#'))
y5h3 = np.loadtxt('./current_data/Eh3bond5series.dat', usecols=(1),unpack=True,comments=('#'))

y1 = yh3dna1 - ydna1 - y1h3
y2 = yh3dna2 - ydna2 - y2h3
y3 = yh3dna3 - ydna3 - y3h3
y4 = yh3dna4 - ydna4 - y4h3
y5 = yh3dna5 - ydna5 - y5h3
EH3 = np.concatenate((y1,y2,y3,y4,y5))


ah4_1 = np.loadtxt('./current_data/Ednah4bond1series.dat', usecols = (1), unpack = True, comments=('#'))
a1h4 = np.loadtxt('./current_data/Eh4bond1series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_2 = np.loadtxt('./current_data/Ednah4bond2series.dat', usecols = (1), unpack = True, comments=('#'))
a2h4 = np.loadtxt('./current_data/Eh4bond2series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_3 = np.loadtxt('./current_data/Ednah4bond3series.dat', usecols = (1), unpack = True, comments=('#'))
a3h4 = np.loadtxt('./current_data/Eh4bond3series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_4 = np.loadtxt('./current_data/Ednah4bond4series.dat', usecols = (1), unpack = True, comments=('#'))
a4h4 = np.loadtxt('./current_data/Eh4bond4series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_5 = np.loadtxt('./current_data/Ednah4bond5series.dat', usecols = (1), unpack = True, comments=('#'))
a5h4 = np.loadtxt('./current_data/Eh4bond5series.dat', usecols=(1),unpack=True,comments=('#'))

a1 = ah4_1 - ydna1 - a1h4
a2 = ah4_2 - ydna2 - a2h4
a3 = ah4_3 - ydna3 - a3h4
a4 = ah4_4 - ydna4 - a4h4
a5 = ah4_5 - ydna5 - a5h4
EH4 = np.concatenate((a1,a2,a3,a4,a5))

bh2a_1 = np.loadtxt('./current_data/Ednah2abond1series.dat', usecols = (1), unpack = True, comments=('#'))
b1h2a = np.loadtxt('./current_data/Eh2abond1series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_2 = np.loadtxt('./current_data/Ednah2abond2series.dat', usecols = (1), unpack = True, comments=('#'))
b2h2a = np.loadtxt('./current_data/Eh2abond2series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_3 = np.loadtxt('./current_data/Ednah2abond3series.dat', usecols = (1), unpack = True, comments=('#'))
b3h2a = np.loadtxt('./current_data/Eh2abond3series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_4 = np.loadtxt('./current_data/Ednah2abond4series.dat', usecols = (1), unpack = True, comments=('#'))
b4h2a = np.loadtxt('./current_data/Eh2abond4series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_5 = np.loadtxt('./current_data/Ednah2abond5series.dat', usecols = (1), unpack = True, comments=('#'))
b5h2a = np.loadtxt('./current_data/Eh2abond5series.dat', usecols=(1),unpack=True,comments=('#'))

b1 = bh2a_1 - ydna1 - b1h2a
b2 = bh2a_2 - ydna2 - b2h2a
b3 = bh2a_3 - ydna3 - b3h2a
b4 = bh2a_4 - ydna4 - b4h2a
b5 = bh2a_5 - ydna5 - b5h2a
EH2a = np.concatenate((b1,b2,b3,b4,b5))

ch2b_1 = np.loadtxt('./current_data/Ednah2bbond1series.dat', usecols = (1), unpack = True, comments=('#'))
c1h2b = np.loadtxt('./current_data/Eh2bbond1series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_2 = np.loadtxt('./current_data/Ednah2bbond2series.dat', usecols = (1), unpack = True, comments=('#'))
c2h2b = np.loadtxt('./current_data/Eh2bbond2series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_3 = np.loadtxt('./current_data/Ednah2bbond3series.dat', usecols = (1), unpack = True, comments=('#'))
c3h2b = np.loadtxt('./current_data/Eh2bbond3series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_4 = np.loadtxt('./current_data/Ednah2bbond4series.dat', usecols = (1), unpack = True, comments=('#'))
c4h2b = np.loadtxt('./current_data/Eh2bbond4series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_5 = np.loadtxt('./current_data/Ednah2bbond5series.dat', usecols = (1), unpack = True, comments=('#'))
c5h2b = np.loadtxt('./current_data/Eh2bbond5series.dat', usecols=(1),unpack=True,comments=('#'))

c1 = ch2b_1 - ydna1 - c1h2b
c2 = ch2b_2 - ydna2 - c2h2b
c3 = ch2b_3 - ydna3 - c3h2b
c4 = ch2b_4 - ydna4 - c4h2b
c5 = ch2b_5 - ydna5 - c5h2b
EH2b = np.concatenate((c1,c2,c3,c4,c5))

# NucE, H3

y1h3_1 = np.loadtxt('./NCP_tail_hbonds/Etail1h3bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h3_2 = np.loadtxt('./NCP_tail_hbonds/Etail2h3bond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h3_1 = np.loadtxt('./NCP_tail_hbonds/Etail1h3bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h3_2 = np.loadtxt('./NCP_tail_hbonds/Etail2h3bond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h3_1 = np.loadtxt('./NCP_tail_hbonds/Etail1h3bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h3_2 = np.loadtxt('./NCP_tail_hbonds/Etail2h3bond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h3_1 = np.loadtxt('./NCP_tail_hbonds/Etail1h3bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h3_2 = np.loadtxt('./NCP_tail_hbonds/Etail2h3bond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h3_1 = np.loadtxt('./NCP_tail_hbonds/Etail1h3bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h3_2 = np.loadtxt('./NCP_tail_hbonds/Etail2h3bond5.dat', usecols=(1),unpack=True,comments=('#'))
EH3_1 = np.concatenate((y1h3_1-ydna1, y2h3_1-ydna2, y3h3_1-ydna3, y4h3_1-ydna4, y5h3_1-ydna5))
EH3_2 = np.concatenate((y1h3_2-ydna1, y2h3_2-ydna2, y3h3_2-ydna3, y4h3_2-ydna4, y5h3_2-ydna5))

#H4

y1h4_1 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail1bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h4_2 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail2bond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h4_1 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail1bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h4_2 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail2bond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h4_1 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail1bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h4_2 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail2bond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h4_1 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail1bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h4_2 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail2bond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h4_1 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail1bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h4_2 = np.loadtxt('./NCP_tail_hbonds/Eh4_tail2bond5.dat', usecols=(1),unpack=True,comments=('#'))
EH4_1 = np.concatenate((y1h4_1-ydna1, y2h4_1-ydna2, y3h4_1-ydna3, y4h4_1-ydna4, y5h4_1-ydna5))
EH4_2 = np.concatenate((y1h4_2-ydna1, y2h4_2-ydna2, y3h4_2-ydna3, y4h4_2-ydna4, y5h4_2-ydna5))

#H2a

y1h2a_1 = np.loadtxt('./NCP_tail_hbonds/Eh2a_1bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h2a_2 = np.loadtxt('./NCP_tail_hbonds/Eh2abond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2a_1 = np.loadtxt('./NCP_tail_hbonds/Eh2a_1bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h2a_2 = np.loadtxt('./NCP_tail_hbonds/Eh2abond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2a_1 = np.loadtxt('./NCP_tail_hbonds/Eh2a_1bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h2a_2 = np.loadtxt('./NCP_tail_hbonds/Eh2abond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2a_1 = np.loadtxt('./NCP_tail_hbonds/Eh2a_1bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h2a_2 = np.loadtxt('./NCP_tail_hbonds/Eh2abond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2a_1 = np.loadtxt('./NCP_tail_hbonds/Eh2a_1bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h2a_2 = np.loadtxt('./NCP_tail_hbonds/Eh2abond5.dat', usecols=(1),unpack=True,comments=('#'))
EH2a_1 = np.concatenate((y1h2a_1-ydna1, y2h2a_1-ydna2, y3h2a_1-ydna3, y4h2a_1-ydna4, y5h2a_1-ydna5))
EH2a_2 = np.concatenate((y1h2a_2-ydna1, y2h2a_2-ydna2, y3h2a_2-ydna3, y4h2a_2-ydna4, y5h2a_2-ydna5))

#H2b

y1h2b_1 = np.loadtxt('./NCP_tail_hbonds/Eh2b_1bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h2b_2 = np.loadtxt('./NCP_tail_hbonds/Eh2bbond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2b_1 = np.loadtxt('./NCP_tail_hbonds/Eh2b_1bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h2b_2 = np.loadtxt('./NCP_tail_hbonds/Eh2bbond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2b_1 = np.loadtxt('./NCP_tail_hbonds/Eh2b_1bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h2b_2 = np.loadtxt('./NCP_tail_hbonds/Eh2bbond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2b_1 = np.loadtxt('./NCP_tail_hbonds/Eh2b_1bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h2b_2 = np.loadtxt('./NCP_tail_hbonds/Eh2bbond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2b_1 = np.loadtxt('./NCP_tail_hbonds/Eh2b_1bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h2b_2 = np.loadtxt('./NCP_tail_hbonds/Eh2bbond5.dat', usecols=(1),unpack=True,comments=('#'))
EH2b_1 = np.concatenate((y1h2b_1-ydna1, y2h2b_1-ydna2, y3h2b_1-ydna3, y4h2b_1-ydna4, y5h2b_1-ydna5))
EH2b_2 = np.concatenate((y1h2b_2-ydna1, y2h2b_2-ydna2, y3h2b_2-ydna3, y4h2b_2-ydna4, y5h2b_2-ydna5))

# %%
# EnoB

x, yh3dna1 = np.loadtxt('./current_data/EnoBdnah3bond1series.dat', usecols = (0,1), unpack = True, comments=('#'))
ydna1 = np.loadtxt('./current_data/EnoBdnaseries1.dat', usecols = (1), unpack = True, comments=('#'))
y1h3 = np.loadtxt('./current_data/EnoBh3bond1series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna2 = np.loadtxt('./current_data/EnoBdnah3bond2series.dat', usecols = (1), unpack = True, comments=('#'))
ydna2 = np.loadtxt('./current_data/EnoBdnaseries2.dat', usecols = (1), unpack = True, comments=('#'))
y2h3 = np.loadtxt('./current_data/EnoBh3bond2series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna3 = np.loadtxt('./current_data/EnoBdnah3bond3series.dat', usecols = (1), unpack = True, comments=('#'))
ydna3 = np.loadtxt('./current_data/EnoBdnaseries3.dat', usecols = (1), unpack = True, comments=('#'))
y3h3 = np.loadtxt('./current_data/EnoBh3bond3series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna4 = np.loadtxt('./current_data/EnoBdnah3bond4series.dat', usecols = (1), unpack = True, comments=('#'))
ydna4 = np.loadtxt('./current_data/EnoBdnaseries4.dat', usecols = (1), unpack = True, comments=('#'))
y4h3 = np.loadtxt('./current_data/EnoBh3bond4series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna5 = np.loadtxt('./current_data/EnoBdnah3bond5series.dat', usecols = (1), unpack = True, comments=('#'))
ydna5 = np.loadtxt('./current_data/EnoBdnaseries5.dat', usecols = (1), unpack = True, comments=('#'))
y5h3 = np.loadtxt('./current_data/EnoBh3bond5series.dat', usecols=(1),unpack=True,comments=('#'))

y1 = yh3dna1 - ydna1 - y1h3
y2 = yh3dna2 - ydna2 - y2h3
y3 = yh3dna3 - ydna3 - y3h3
y4 = yh3dna4 - ydna4 - y4h3
y5 = yh3dna5 - ydna5 - y5h3
EnoBH3 = np.concatenate((y1,y2,y3,y4,y5))


ah4_1 = np.loadtxt('./current_data/EnoBdnah4bond1series.dat', usecols = (1), unpack = True, comments=('#'))
a1h4 = np.loadtxt('./current_data/EnoBh4bond1series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_2 = np.loadtxt('./current_data/EnoBdnah4bond2series.dat', usecols = (1), unpack = True, comments=('#'))
a2h4 = np.loadtxt('./current_data/EnoBh4bond2series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_3 = np.loadtxt('./current_data/EnoBdnah4bond3series.dat', usecols = (1), unpack = True, comments=('#'))
a3h4 = np.loadtxt('./current_data/EnoBh4bond3series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_4 = np.loadtxt('./current_data/EnoBdnah4bond4series.dat', usecols = (1), unpack = True, comments=('#'))
a4h4 = np.loadtxt('./current_data/EnoBh4bond4series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_5 = np.loadtxt('./current_data/EnoBdnah4bond5series.dat', usecols = (1), unpack = True, comments=('#'))
a5h4 = np.loadtxt('./current_data/EnoBh4bond5series.dat', usecols=(1),unpack=True,comments=('#'))

a1 = ah4_1 - ydna1 - a1h4
a2 = ah4_2 - ydna2 - a2h4
a3 = ah4_3 - ydna3 - a3h4
a4 = ah4_4 - ydna4 - a4h4
a5 = ah4_5 - ydna5 - a5h4
EnoBH4 = np.concatenate((a1,a2,a3,a4,a5))

bh2a_1 = np.loadtxt('./current_data/EnoBdnah2abond1series.dat', usecols = (1), unpack = True, comments=('#'))
b1h2a = np.loadtxt('./current_data/EnoBh2abond1series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_2 = np.loadtxt('./current_data/EnoBdnah2abond2series.dat', usecols = (1), unpack = True, comments=('#'))
b2h2a = np.loadtxt('./current_data/EnoBh2abond2series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_3 = np.loadtxt('./current_data/EnoBdnah2abond3series.dat', usecols = (1), unpack = True, comments=('#'))
b3h2a = np.loadtxt('./current_data/EnoBh2abond3series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_4 = np.loadtxt('./current_data/EnoBdnah2abond4series.dat', usecols = (1), unpack = True, comments=('#'))
b4h2a = np.loadtxt('./current_data/EnoBh2abond4series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_5 = np.loadtxt('./current_data/EnoBdnah2abond5series.dat', usecols = (1), unpack = True, comments=('#'))
b5h2a = np.loadtxt('./current_data/EnoBh2abond5series.dat', usecols=(1),unpack=True,comments=('#'))

b1 = bh2a_1 - ydna1 - b1h2a
b2 = bh2a_2 - ydna2 - b2h2a
b3 = bh2a_3 - ydna3 - b3h2a
b4 = bh2a_4 - ydna4 - b4h2a
b5 = bh2a_5 - ydna5 - b5h2a
EnoBH2a = np.concatenate((b1,b2,b3,b4,b5))

ch2b_1 = np.loadtxt('./current_data/EnoBdnah2bbond1series.dat', usecols = (1), unpack = True, comments=('#'))
c1h2b = np.loadtxt('./current_data/EnoBh2bbond1series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_2 = np.loadtxt('./current_data/EnoBdnah2bbond2series.dat', usecols = (1), unpack = True, comments=('#'))
c2h2b = np.loadtxt('./current_data/EnoBh2bbond2series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_3 = np.loadtxt('./current_data/EnoBdnah2bbond3series.dat', usecols = (1), unpack = True, comments=('#'))
c3h2b = np.loadtxt('./current_data/EnoBh2bbond3series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_4 = np.loadtxt('./current_data/EnoBdnah2bbond4series.dat', usecols = (1), unpack = True, comments=('#'))
c4h2b = np.loadtxt('./current_data/EnoBh2bbond4series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_5 = np.loadtxt('./current_data/EnoBdnah2bbond5series.dat', usecols = (1), unpack = True, comments=('#'))
c5h2b = np.loadtxt('./current_data/EnoBh2bbond5series.dat', usecols=(1),unpack=True,comments=('#'))

c1 = ch2b_1 - ydna1 - c1h2b
c2 = ch2b_2 - ydna2 - c2h2b
c3 = ch2b_3 - ydna3 - c3h2b
c4 = ch2b_4 - ydna4 - c4h2b
c5 = ch2b_5 - ydna5 - c5h2b
EnoBH2b = np.concatenate((c1,c2,c3,c4,c5))


# NucE, H3

y1h3_1 = np.loadtxt('./NCP_tail_hbonds/EnoBtail1h3bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h3_2 = np.loadtxt('./NCP_tail_hbonds/EnoBtail2h3bond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h3_1 = np.loadtxt('./NCP_tail_hbonds/EnoBtail1h3bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h3_2 = np.loadtxt('./NCP_tail_hbonds/EnoBtail2h3bond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h3_1 = np.loadtxt('./NCP_tail_hbonds/EnoBtail1h3bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h3_2 = np.loadtxt('./NCP_tail_hbonds/EnoBtail2h3bond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h3_1 = np.loadtxt('./NCP_tail_hbonds/EnoBtail1h3bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h3_2 = np.loadtxt('./NCP_tail_hbonds/EnoBtail2h3bond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h3_1 = np.loadtxt('./NCP_tail_hbonds/EnoBtail1h3bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h3_2 = np.loadtxt('./NCP_tail_hbonds/EnoBtail2h3bond5.dat', usecols=(1),unpack=True,comments=('#'))
EnoBH3_1 = np.concatenate((y1h3_1-ydna1, y2h3_1-ydna2, y3h3_1-ydna3, y4h3_1-ydna4, y5h3_1-ydna5))
EnoBH3_2 = np.concatenate((y1h3_2-ydna1, y2h3_2-ydna2, y3h3_2-ydna3, y4h3_2-ydna4, y5h3_2-ydna5))

#H4

y1h4_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail1bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h4_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail2bond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h4_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail1bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h4_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail2bond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h4_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail1bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h4_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail2bond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h4_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail1bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h4_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail2bond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h4_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail1bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h4_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh4_tail2bond5.dat', usecols=(1),unpack=True,comments=('#'))
EnoBH4_1 = np.concatenate((y1h4_1-ydna1, y2h4_1-ydna2, y3h4_1-ydna3, y4h4_1-ydna4, y5h4_1-ydna5))
EnoBH4_2 = np.concatenate((y1h4_2-ydna1, y2h4_2-ydna2, y3h4_2-ydna3, y4h4_2-ydna4, y5h4_2-ydna5))

#H2a

y1h2a_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2a_1bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h2a_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2abond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2a_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2a_1bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h2a_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2abond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2a_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2a_1bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h2a_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2abond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2a_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2a_1bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h2a_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2abond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2a_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2a_1bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h2a_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2abond5.dat', usecols=(1),unpack=True,comments=('#'))
EnoBH2a_1 = np.concatenate((y1h2a_1-ydna1, y2h2a_1-ydna2, y3h2a_1-ydna3, y4h2a_1-ydna4, y5h2a_1-ydna5))
EnoBH2a_2 = np.concatenate((y1h2a_2-ydna1, y2h2a_2-ydna2, y3h2a_2-ydna3, y4h2a_2-ydna4, y5h2a_2-ydna5))

#H2b

y1h2b_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2b_1bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h2b_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2bbond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2b_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2b_1bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h2b_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2bbond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2b_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2b_1bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h2b_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2bbond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2b_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2b_1bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h2b_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2bbond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2b_1 = np.loadtxt('./NCP_tail_hbonds/EnoBh2b_1bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h2b_2 = np.loadtxt('./NCP_tail_hbonds/EnoBh2bbond5.dat', usecols=(1),unpack=True,comments=('#'))
EnoBH2b_1 = np.concatenate((y1h2b_1-ydna1, y2h2b_1-ydna2, y3h2b_1-ydna3, y4h2b_1-ydna4, y5h2b_1-ydna5))
EnoBH2b_2 = np.concatenate((y1h2b_2-ydna1, y2h2b_2-ydna2, y3h2b_2-ydna3, y4h2b_2-ydna4, y5h2b_2-ydna5))

# %%
# NucM

x, yh3dna1 = np.loadtxt('./current_data/Mdnah3bond1series.dat', usecols = (0,1), unpack = True, comments=('#'))
ydna1 = np.loadtxt('./current_data/Mdnaseries1.dat', usecols = (1), unpack = True, comments=('#'))
y1h3 = np.loadtxt('./current_data/Mh3bond1series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna2 = np.loadtxt('./current_data/Mdnah3bond2series.dat', usecols = (1), unpack = True, comments=('#'))
ydna2 = np.loadtxt('./current_data/Mdnaseries2.dat', usecols = (1), unpack = True, comments=('#'))
y2h3 = np.loadtxt('./current_data/Mh3bond2series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna3 = np.loadtxt('./current_data/Mdnah3bond3series.dat', usecols = (1), unpack = True, comments=('#'))
ydna3 = np.loadtxt('./current_data/Mdnaseries3.dat', usecols = (1), unpack = True, comments=('#'))
y3h3 = np.loadtxt('./current_data/Mh3bond3series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna4 = np.loadtxt('./current_data/Mdnah3bond4series.dat', usecols = (1), unpack = True, comments=('#'))
ydna4 = np.loadtxt('./current_data/Mdnaseries4.dat', usecols = (1), unpack = True, comments=('#'))
y4h3 = np.loadtxt('./current_data/Mh3bond4series.dat', usecols=(1),unpack=True,comments=('#'))

yh3dna5 = np.loadtxt('./current_data/Mdnah3bond5series.dat', usecols = (1), unpack = True, comments=('#'))
ydna5 = np.loadtxt('./current_data/Mdnaseries5.dat', usecols = (1), unpack = True, comments=('#'))
y5h3 = np.loadtxt('./current_data/Mh3bond5series.dat', usecols=(1),unpack=True,comments=('#'))

y1 = yh3dna1 - ydna1 - y1h3
y2 = yh3dna2 - ydna2 - y2h3
y3 = yh3dna3 - ydna3 - y3h3
y4 = yh3dna4 - ydna4 - y4h3
y5 = yh3dna5 - ydna5 - y5h3
MH3 = np.concatenate((y1,y2,y3,y4,y5))


ah4_1 = np.loadtxt('./current_data/Mdnah4bond1series.dat', usecols = (1), unpack = True, comments=('#'))
a1h4 = np.loadtxt('./current_data/Mh4bond1series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_2 = np.loadtxt('./current_data/Mdnah4bond2series.dat', usecols = (1), unpack = True, comments=('#'))
a2h4 = np.loadtxt('./current_data/Mh4bond2series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_3 = np.loadtxt('./current_data/Mdnah4bond3series.dat', usecols = (1), unpack = True, comments=('#'))
a3h4 = np.loadtxt('./current_data/Mh4bond3series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_4 = np.loadtxt('./current_data/Mdnah4bond4series.dat', usecols = (1), unpack = True, comments=('#'))
a4h4 = np.loadtxt('./current_data/Mh4bond4series.dat', usecols=(1),unpack=True,comments=('#'))
ah4_5 = np.loadtxt('./current_data/Mdnah4bond5series.dat', usecols = (1), unpack = True, comments=('#'))
a5h4 = np.loadtxt('./current_data/Mh4bond5series.dat', usecols=(1),unpack=True,comments=('#'))

a1 = ah4_1 - ydna1 - a1h4
a2 = ah4_2 - ydna2 - a2h4
a3 = ah4_3 - ydna3 - a3h4
a4 = ah4_4 - ydna4 - a4h4
a5 = ah4_5 - ydna5 - a5h4
MH4 = np.concatenate((a1,a2,a3,a4,a5))

bh2a_1 = np.loadtxt('./current_data/Mdnah2abond1series.dat', usecols = (1), unpack = True, comments=('#'))
b1h2a = np.loadtxt('./current_data/Mh2abond1series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_2 = np.loadtxt('./current_data/Mdnah2abond2series.dat', usecols = (1), unpack = True, comments=('#'))
b2h2a = np.loadtxt('./current_data/Mh2abond2series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_3 = np.loadtxt('./current_data/Mdnah2abond3series.dat', usecols = (1), unpack = True, comments=('#'))
b3h2a = np.loadtxt('./current_data/Mh2abond3series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_4 = np.loadtxt('./current_data/Mdnah2abond4series.dat', usecols = (1), unpack = True, comments=('#'))
b4h2a = np.loadtxt('./current_data/Mh2abond4series.dat', usecols=(1),unpack=True,comments=('#'))
bh2a_5 = np.loadtxt('./current_data/Mdnah2abond5series.dat', usecols = (1), unpack = True, comments=('#'))
b5h2a = np.loadtxt('./current_data/Mh2abond5series.dat', usecols=(1),unpack=True,comments=('#'))

b1 = bh2a_1 - ydna1 - b1h2a
b2 = bh2a_2 - ydna2 - b2h2a
b3 = bh2a_3 - ydna3 - b3h2a
b4 = bh2a_4 - ydna4 - b4h2a
b5 = bh2a_5 - ydna5 - b5h2a
MH2a = np.concatenate((b1,b2,b3,b4,b5))

ch2b_1 = np.loadtxt('./current_data/Mdnah2bbond1series.dat', usecols = (1), unpack = True, comments=('#'))
c1h2b = np.loadtxt('./current_data/Mh2bbond1series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_2 = np.loadtxt('./current_data/Mdnah2bbond2series.dat', usecols = (1), unpack = True, comments=('#'))
c2h2b = np.loadtxt('./current_data/Mh2bbond2series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_3 = np.loadtxt('./current_data/Mdnah2bbond3series.dat', usecols = (1), unpack = True, comments=('#'))
c3h2b = np.loadtxt('./current_data/Mh2bbond3series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_4 = np.loadtxt('./current_data/Mdnah2bbond4series.dat', usecols = (1), unpack = True, comments=('#'))
c4h2b = np.loadtxt('./current_data/Mh2bbond4series.dat', usecols=(1),unpack=True,comments=('#'))
ch2b_5 = np.loadtxt('./current_data/Mdnah2bbond5series.dat', usecols = (1), unpack = True, comments=('#'))
c5h2b = np.loadtxt('./current_data/Mh2bbond5series.dat', usecols=(1),unpack=True,comments=('#'))

c1 = ch2b_1 - ydna1 - c1h2b
c2 = ch2b_2 - ydna2 - c2h2b
c3 = ch2b_3 - ydna3 - c3h2b
c4 = ch2b_4 - ydna4 - c4h2b
c5 = ch2b_5 - ydna5 - c5h2b
MH2b = np.concatenate((c1,c2,c3,c4,c5))

# NucM, H3

y1h3_1 = np.loadtxt('./NCP_tail_hbonds/Mtail1h3bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h3_2 = np.loadtxt('./NCP_tail_hbonds/Mtail2h3bond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h3_1 = np.loadtxt('./NCP_tail_hbonds/Mtail1h3bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h3_2 = np.loadtxt('./NCP_tail_hbonds/Mtail2h3bond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h3_1 = np.loadtxt('./NCP_tail_hbonds/Mtail1h3bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h3_2 = np.loadtxt('./NCP_tail_hbonds/Mtail2h3bond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h3_1 = np.loadtxt('./NCP_tail_hbonds/Mtail1h3bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h3_2 = np.loadtxt('./NCP_tail_hbonds/Mtail2h3bond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h3_1 = np.loadtxt('./NCP_tail_hbonds/Mtail1h3bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h3_2 = np.loadtxt('./NCP_tail_hbonds/Mtail2h3bond5.dat', usecols=(1),unpack=True,comments=('#'))
MH3_1 = np.concatenate((y1h3_1-ydna1, y2h3_1-ydna2, y3h3_1-ydna3, y4h3_1-ydna4, y5h3_1-ydna5))
MH3_2 = np.concatenate((y1h3_2-ydna1, y2h3_2-ydna2, y3h3_2-ydna3, y4h3_2-ydna4, y5h3_2-ydna5))

#H4

y1h4_1 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail1bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h4_2 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail2bond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h4_1 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail1bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h4_2 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail2bond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h4_1 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail1bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h4_2 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail2bond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h4_1 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail1bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h4_2 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail2bond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h4_1 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail1bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h4_2 = np.loadtxt('./NCP_tail_hbonds/Mh4_tail2bond5.dat', usecols=(1),unpack=True,comments=('#'))
MH4_1 = np.concatenate((y1h4_1-ydna1, y2h4_1-ydna2, y3h4_1-ydna3, y4h4_1-ydna4, y5h4_1-ydna5))
MH4_2 = np.concatenate((y1h4_2-ydna1, y2h4_2-ydna2, y3h4_2-ydna3, y4h4_2-ydna4, y5h4_2-ydna5))

#H2a

y1h2a_1 = np.loadtxt('./NCP_tail_hbonds/Mh2a_1bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h2a_2 = np.loadtxt('./NCP_tail_hbonds/Mh2abond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2a_1 = np.loadtxt('./NCP_tail_hbonds/Mh2a_1bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h2a_2 = np.loadtxt('./NCP_tail_hbonds/Mh2abond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2a_1 = np.loadtxt('./NCP_tail_hbonds/Mh2a_1bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h2a_2 = np.loadtxt('./NCP_tail_hbonds/Mh2abond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2a_1 = np.loadtxt('./NCP_tail_hbonds/Mh2a_1bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h2a_2 = np.loadtxt('./NCP_tail_hbonds/Mh2abond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2a_1 = np.loadtxt('./NCP_tail_hbonds/Mh2a_1bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h2a_2 = np.loadtxt('./NCP_tail_hbonds/Mh2abond5.dat', usecols=(1),unpack=True,comments=('#'))
MH2a_1 = np.concatenate((y1h2a_1-ydna1, y2h2a_1-ydna2, y3h2a_1-ydna3, y4h2a_1-ydna4, y5h2a_1-ydna5))
MH2a_2 = np.concatenate((y1h2a_2-ydna1, y2h2a_2-ydna2, y3h2a_2-ydna3, y4h2a_2-ydna4, y5h2a_2-ydna5))

#H2b

y1h2b_1 = np.loadtxt('./NCP_tail_hbonds/Mh2b_1bond1.dat', usecols = (1), unpack = True, comments=('#'))
y1h2b_2 = np.loadtxt('./NCP_tail_hbonds/Mh2bbond1.dat', usecols=(1),unpack=True,comments=('#'))
y2h2b_1 = np.loadtxt('./NCP_tail_hbonds/Mh2b_1bond2.dat', usecols = (1), unpack = True, comments=('#'))
y2h2b_2 = np.loadtxt('./NCP_tail_hbonds/Mh2bbond2.dat', usecols=(1),unpack=True,comments=('#'))
y3h2b_1 = np.loadtxt('./NCP_tail_hbonds/Mh2b_1bond3.dat', usecols = (1), unpack = True, comments=('#'))
y3h2b_2 = np.loadtxt('./NCP_tail_hbonds/Mh2bbond3.dat', usecols=(1),unpack=True,comments=('#'))
y4h2b_1 = np.loadtxt('./NCP_tail_hbonds/Mh2b_1bond4.dat', usecols = (1), unpack = True, comments=('#'))
y4h2b_2 = np.loadtxt('./NCP_tail_hbonds/Mh2bbond4.dat', usecols=(1),unpack=True,comments=('#'))
y5h2b_1 = np.loadtxt('./NCP_tail_hbonds/Mh2b_1bond5.dat', usecols = (1), unpack = True, comments=('#'))
y5h2b_2 = np.loadtxt('./NCP_tail_hbonds/Mh2bbond5.dat', usecols=(1),unpack=True,comments=('#'))
MH2b_1 = np.concatenate((y1h2b_1-ydna1, y2h2b_1-ydna2, y3h2b_1-ydna3, y4h2b_1-ydna4, y5h2b_1-ydna5))
MH2b_2 = np.concatenate((y1h2b_2-ydna1, y2h2b_2-ydna2, y3h2b_2-ydna3, y4h2b_2-ydna4, y5h2b_2-ydna5))

# %%
import matplotlib.pyplot as plt
import numpy as np

font = {'family': 'sans-serif',
        'color':  'black',
        'size': 12,
        }
        
label = ['NCP', 'PHD + NCP', 'BPTF + NCP']
h3 = np.array([stat.mean(MH3), stat.mean(EnoBH3), stat.mean(EH3)])
h4=np.array([stat.mean(MH4), stat.mean(EnoBH4), stat.mean(EH4)])
h2a = np.array([stat.mean(MH2a), stat.mean(EnoBH2a), stat.mean(EH2a)])
h2b = np.array([stat.mean(MH2b), stat.mean(EnoBH2b), stat.mean(EH2b)])


h3_sd = np.array([stat.stdev(MH3)/2.2, stat.stdev(EnoBH3)/2.2, stat.stdev(EH3)/2.2])
h4_sd = np.array([stat.stdev(MH4)/2.2, stat.stdev(EnoBH4)/2.2, stat.stdev(EH4)/2.2])
h2a_sd = np.array([stat.stdev(MH2a)/2.2, stat.stdev(EnoBH2a)/2.2, stat.stdev(EH2a)/2.2])
h2b_sd = np.array([stat.stdev(MH2b)/2.2, stat.stdev(EnoBH2b)/2.2, stat.stdev(EH2b)/2.2])

width = 0.35       # the width of the bars: can also be len(x) sequence


#plt.figure(figsize=(8.5,6.47))
plt.figure(figsize=(5,3.5))

plt.bar(label, h4, width, yerr=h4_sd, capsize = 3, bottom=h2a+h2b+h3, label='H4', color='green')
plt.bar(label, h3, width, yerr=h3_sd, capsize = 3, bottom=h2a+h2b, label='H3', color='blue')
plt.bar(label, h2b, width, yerr=h2b_sd, capsize = 3, bottom=h2a, label='H2b', color='red')
plt.bar(label, h2a, width, yerr=h2a_sd, capsize = 3, label="H2a", color='yellow')
plt.ylabel('Hydrogen Bonds', fontdict=font)
plt.title('Histone Hydrogen Bonds with DNA', fontdict=font)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(bbox_to_anchor=(1.0, 0.75), fontsize=10)
plt.tight_layout()

plt.savefig('Hbonds_dif.pdf')

# %%
print("H3 tails have "+str(stat.mean(MH3_1+MH3_2-EnoBH3_1-EnoBH3_2))+" less Hbonds on average in PHD systems, or "+str(stat.mean(MH3-EnoBH3))+" less H3 bonds in general.")
print("H3 tails have "+str(stat.mean(MH3_1+MH3_2-EH3_1-EH3_2))+" less Hbonds on average in BPTF systems, or "+str(stat.mean(MH3-EH3))+" less H3 bonds in general.")
print("H4 tails have "+str(stat.mean(MH4_1+MH4_2-EnoBH4_1-EnoBH4_2))+" less Hbonds on average in PHD systems, or "+str(stat.mean(MH4-EnoBH4))+" less H3 bonds in general.")
print("H4 tails have "+str(stat.mean(MH4_1+MH4_2-EH4_1-EH4_2))+" less Hbonds on average in BPTF systems, or "+str(stat.mean(MH4-EH4))+" less H3 bonds in general.")
print("H2a tails have "+str(stat.mean(MH2a_1+MH2a_2-EnoBH2a_1-EnoBH2a_2))+" less Hbonds on average in PHD systems, or "+str(stat.mean(MH2a-EnoBH2a))+" less H3 bonds in general.")
print("H2a tails have "+str(stat.mean(MH2a_1+MH2a_2-EH2a_1-EH2a_2))+" less Hbonds on average in BPTF systems, or "+str(stat.mean(MH2a-EH2a))+" less H3 bonds in general.")
print("H2b tails have "+str(stat.mean(MH2b_1+MH2b_2-EnoBH2b_1-EnoBH2b_2))+" less Hbonds on average in PHD systems, or "+str(stat.mean(MH2b-EnoBH2b))+" less H3 bonds in general.")
print("H2b tails have "+str(stat.mean(MH2b_1+MH2b_2-EH2b_1-EH2b_2))+" less Hbonds on average in BPTF systems, or "+str(stat.mean(MH2b-EH2b))+" less H3 bonds in general.")

# %%
print(str(stat.mean(EnoBH3))+" +/- "+str(stat.stdev(EnoBH3)/2.2)+" H3 bonds in PHD systems.")
print(str(stat.mean(EH3))+" +/- "+str(stat.stdev(EH3)/2.2)+" H3 bonds in BPTF systems.")
print(str(stat.mean(EnoBH4))+" +/- "+str(stat.stdev(EnoBH4)/2.2)+" H4 bonds in PHD systems.")
print(str(stat.mean(EH4))+" +/- "+str(stat.stdev(EH4)/2.2)+" H4 bonds in BPTF systems.")
print(str(stat.mean(EnoBH2a))+" +/- "+str(stat.stdev(EnoBH2a)/2.2)+" H2a bonds in PHD systems.")
print(str(stat.mean(EH2a))+" +/- "+str(stat.stdev(EH2a)/2.2)+" H2a bonds in BPTF systems.")
print(str(stat.mean(EnoBH2b))+" +/- "+str(stat.stdev(EnoBH2b)/2.2)+" H2b bonds in PHD systems.")
print(str(stat.mean(EH2b))+" +/- "+str(stat.stdev(EH2b)/2.2)+" H2b bonds in BPTF systems.")
